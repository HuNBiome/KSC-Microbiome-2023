# %%
#lastest sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from pycaret.classification import *

# %%
modelfile = "model_39pars"
config = load_config(modelfile)
model = load_model(modelfile)
plot_model(model['trained_model'], plot='auc', save=False, scale=5)
